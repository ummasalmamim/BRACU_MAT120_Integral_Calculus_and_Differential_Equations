# %% [markdown]
# #**Course Tittle: Mathematics II: Integral Calculus & Differential Equations**
# **Name: UMMA SALMA MIM\
#  ID: 2210******* \
#  Section: 7\
#  Couese Code: MAT120\
#  Semester: Summer2023\
#  Lab Class No: 1

# %%
import numpy as np
x=3+2j
print(np.conj(x))                      #print it's conjugate number
# Out:
# (3-2j)

# %%
from sympy  import*

# %%
x=Symbol("x")
f=x**2+x+1
print("f(x)=",f)
# Out:
# f(x)= x**2 + x + 1

# %%
x=Symbol("x")
y,z=symbols("y,z")
h=sin(x)+cos(y)+tan(z)
print("f(x,y,z)=",h)
# Out:
# f(x,y,z)= sin(x) + cos(y) + tan(z)

# %%
x=Symbol("x")
f=x**2+x+1
print("f(x)=",f)
a=f.subs(x,2)
print("f(2)=",a)
# Out:
# f(x)= x**2 + x + 1
# f(2)= 7

# %%
x=Symbol("x")
y,z=symbols("y,z")
h=sin(x)+cos(y)+tan(z)
print("f(x,y,z)=",h)
b=h.subs([(x,30), (y,45), (z,60)])
print("f(30,45,60)=",b)
# Out:
# f(x,y,z)= sin(x) + cos(y) + tan(z)
# f(30,45,60)= sin(30) + tan(60) + cos(45)

# %%
j=sin(x)
print(j.subs(x,pi))
# Out:
# 0

# %%
m=sqrt(12)
print(m)
# Out:
# 2*sqrt(3)

# %%
import math
m=math.sqrt(12)
print(m)
print(Float(m,3))
print(Rational(m))
print(Rational(m).limit_denominator(50))
# Out:
# 3.4641016151377544
# 3.46
# 3900231685776981/1125899906842624
# 97/28

# %%
x=Symbol("x")            #parameter 1 ta hole Symbol hobe ,parameter 2 ta hole symbols hobe
y,z=symbols("y,z")
h=sin(x)+cos(y)+tan(z)        #eikhane sin ,tan,cos er value rediant hisabe ase
print("f(x,y,z)=",h)
l=lambdify([x,y,z],h)    #it like a function
l(2,3,4)
# Out:
# f(x,y,z)= sin(x) + cos(y) + tan(z)
# np.float64(1.0771262125748138)

# %%
x=Symbol("x")            #parameter 1 ta hole Symbol hobe ,parameter 2 ta hole symbols hobe
y,z=symbols("y,z")
h=sin(x)+cos(y)+tan(z)        #eikhane sin ,tan,cos er value rediant hisabe ase
print("f(x,y,z)=",h)
l=lambdify([x,y,z],h)    #it like a function
print(l(2,3,4))
# Out:
# f(x,y,z)= sin(x) + cos(y) + tan(z)
# 1.0771262125748138

# %%
x=Symbol("x")            #parameter 1 ta hole Symbol hobe ,parameter 2 ta hole symbols hobe
y,z=symbols("y,z")
h=sin(x)+cos(y)+tan(z)        #eikhane sin ,tan,cos er value rediant hisabe ase
print("f(x,y,z)=",h)
l=lambdify([x,y,z],h)    #it like a function
l(2,3,4)
print(l)
# Out:
# f(x,y,z)= sin(x) + cos(y) + tan(z)
# <function _lambdifygenerated at 0x7cb4273879c0>

# %%
x=Symbol("x")            #parameter 1 ta hole Symbol hobe ,parameter 2 ta hole symbols hobe
y,z=symbols("y,z")
h=sin(x)+cos(y)+ln(z)        #eikhane sin ,tan,cos er value rediant hisabe ase
print("f(x,y,z)=",h)
l=lambdify([x,y,z],h)    #it like a function
l(2,3,4)
# Out:
# f(x,y,z)= log(z) + sin(x) + cos(y)
# np.float64(1.3055992913451269)

# %%
x=Symbol("x")            #parameter 1 ta hole Symbol hobe ,parameter 2 ta hole symbols hobe
y,z=symbols("y,z")
h=x**2+y+ln(z)        #
print("f(x,y,z)=",h)
l=lambdify([x,z],h)    #it like a function
l(2,3)
# Out:
# f(x,y,z)= x**2 + y + log(z)
# y + 5.09861228866811

# %%
x=Symbol("x")            #parameter 1 ta hole Symbol hobe ,parameter 2 ta hole symbols hobe
y,z=symbols("y,z")
h=x**2+y+ln(z)        # lambdify kora jayna sin,cos,tan,ln,log etc
print("f(x,y,z)=",h)
l=lambdify([x,y,z],h)    #it like a function
l(2,3,4)
# Out:
# f(x,y,z)= x**2 + y + log(z)
# np.float64(8.38629436111989)

# %%
x=Symbol("x")            #parameter 1 ta hole Symbol hobe ,parameter 2 ta hole symbols hobe
y,z=symbols("y,z")
h=x**2+y+z**2        # lambdify kora jay basic maths er jonno for example- sum,product,substritution,division,square etc
print("f(x,y,z)=",h)
l=lambdify([x,y],h)    #it like a function
l(2,3)
# Out:
# f(x,y,z)= x**2 + y + z**2
# z**2 + 7

# %%
f=x**2+x+1
print("f(x)=",f)
df=diff(f)
print("Differentiation of f(x)=",df)
print()

h=sin(x)+cos(y)+tan(z)
print("h(x,y,z)=",h)
dh=diff(h,x)
print("Differentiation of h(x)=",dh)
print()

dh=diff(h,z)
dh = simplify(dh)
print("Differentiation of h(x)=",dh)

p = exp(2*x)
dp = diff(p)
dp
# Out:
# f(x)= x**2 + x + 1
# Differentiation of f(x)= 2*x + 1
#
# h(x,y,z)= sin(x) + cos(y) + tan(z)
# Differentiation of h(x)= cos(x)
#
# Differentiation of h(x)= cos(z)**(-2)
# 2*exp(2*x)
